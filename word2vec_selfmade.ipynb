# %% [markdown]
# # Self Made Word2Vec Embeddings

# %%
import lib
import numpy as np
import spacy
import tensorflow as tf

from functional import seq
from importlib import reload
from joblib import Memory
from lib.data import load_data as load_data_lib
from lib.text_preprocessing import preprocess_tokens, lemmatize, remove_stopwords, to_lower, tokenize, words_only
from lib.vocabulary import Vocabulary
from sklearn.metrics.pairwise import cosine_similarity
from tensorflow import keras
from tqdm import tqdm
from typing import Optional

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# tf.debugging.set_log_device_placement(True)

reload(lib)
# Out:
# Num GPUs Available:  1
# <module 'lib' (namespace)>

# %%
mem = Memory('./data/cache', verbose=0)

# %% [markdown]
# ## Prepare Raw Data

# %%
@mem.cache
def load_data():
    res = load_data_lib()
    return res

data = load_data()
data.head()
# Out:
#                        crawled  \
# 0  2021-02-18T16:16:27.508472Z
# 1  2020-11-19T08:00:00.329121Z
# 2  2020-12-19T10:40:16.731763Z
# 3  2020-11-03T10:00:00.970729Z
# 4  2021-01-22T15:00:00.475531Z
#
#                                                 hash  \
# 0  43d003c39a936c6a25e3fc02f71df795dddc1a0a7aa75d...
# 1  7367d742827140cec892ac6ec940e28160d0cf2bebf300...
# 2  83cd29369d52c1d1e3f132aa672402567c15f66878c719...
# 3  466c496cfcbc46116e0251e1401a363617ea8b14535e85...
# 4  559b96358bbd2132e111507b33e61112d5fad1bbfe89db...
#
#                                               source  \
# 0  https://www.spiegel.de/sport/fussball/juventus...
# 1                  https://www.ard-text.de/mobil/141
# 2  https://www.spiegel.de/politik/ausland/kara-te...
# 3  https://www.spiegel.de/politik/ausland/elfenbe...
# 4  https://www.spiegel.de/geschichte/franzosenhas...
#
#                                                title            type  \
# 0  Zu früher Einsatz nach Krankheit Morata fällt ...  Spiegel Online
# 1                 Ecuador: Illegale Mine eingestürzt    ARD Teletext
# 2  Humanitäre Katastrophe in Griechenland »Babys ...  Spiegel Online
# 3  Umstrittene dritte Amtszeit Präsident Ouattara...  Spiegel Online
# 4  Franzosenhass im 19. Jahrhundert Wie deutsche ...  Spiegel Online
#
#                                                 text lang
# 0  Das Achtelfinalhinspiel der Champions League g...   de
# 1  Beim Einsturz einer Mine in Ecuador sind mehre...   de
# 2  Entwicklungsminister Gerd Müller hat die katas...   de
# 3  Es ist vordergründig ein klarer Sieg für Präsi...   de
# 4  Gefallene Franzosen seien es nicht wert, in de...   de

# %%
data = data[data['lang'] == 'de']
# Out:
# (19975, 7)

# %%
@mem.cache
def preprocess_data():
    return seq(tqdm(data['text'].to_numpy()))\
        .map(lambda text: preprocess_tokens(text, lang, preprocess_pipeline))\
        .to_list()

samples = preprocess_data()
len(samples)
# Out:
# 100%|██████████| 20070/20070 [1:41:49<00:00,  3.28it/s]
# 20070

# %%
#preprocess_data.clear()
#samples[:3]

# %%
vocabulary = seq(tqdm(samples))\
    .fold_left(lib.vocabulary.Vocabulary.builder(), lambda voc, sentence: voc.add_sample(sentence))\
    .build()
vocabulary
# Out:
# 100%|██████████| 20070/20070 [00:01<00:00, 15620.37it/s]
# Vocabulary(name='default', size=170933, default_sample_length=9375)

# %%
list(vocabulary.token2index.items())[1:20]
# Out:
# [('the', 1),
#  ('menschen', 2),
#  ('prozent', 3),
#  ('deutschland', 4),
#  ('millionen', 5),
#  ('laut', 6),
#  ('trump', 7),
#  ('of', 8),
#  ('euro', 9),
#  ('to', 10),
#  ('spiegel', 11),
#  ('pandemie', 12),
#  ('biden', 13),
#  ('deutschen', 14),
#  ('usa', 15),
#  ('and', 16),
#  ('land', 17),
#  ('unternehmen', 18),
#  ('mal', 19)]

# %%
#
# Create model
#

dim = 50

word_input = keras.Input(shape=1)
context_word_input = keras.Input(shape=1)

embedding = keras.layers.Embedding(vocabulary.size, dim, input_length=1, name='embedding')
word_embedding = embedding(word_input)
word = keras.layers.Reshape((dim, 1))(word_embedding)
context_word = keras.layers.Reshape((dim, 1))(embedding(context_word_input))
similarity = keras.layers.Dot(1, normalize=True, name='similarity')([word, context_word])

dot_product = keras.layers.Reshape((1,))(keras.layers.Dot(1, name='dot_product')([word, context_word]))
output = keras.layers.Dense(1, activation=keras.activations.sigmoid, name='output')(dot_product)

model = keras.Model(inputs=[word_input, context_word_input], outputs=output, name="training_model")
model.compile(loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.RMSprop())

validation_model = keras.Model(inputs=[word_input, context_word_input], outputs=similarity, name="validation_model")
embedding_model = keras.Model(inputs=word_input, outputs=word_embedding, name="embedding_model")

model.summary()
# Out:
# Model: "training_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 50)        8546650     input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 50, 1)        0           embedding[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 50, 1)        0           embedding[1][0]
# __________________________________________________________________________________________________
# dot_product (Dot)               (None, 1, 1)         0           reshape_6[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1)            0           dot_product[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            2           reshape_8[0][0]
# ==================================================================================================
# Total params: 8,546,652
# Trainable params: 8,546,652
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
embedding_model.summary()
# Out:
# Model: "embedding_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 1)]               0
# _________________________________________________________________
# embedding (Embedding)        (None, 1, 50)             8546650
# =================================================================
# Total params: 8,546,650
# Trainable params: 8,546,650
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the embedding

# %%
#
# Create a custom generator for generating Training samples from text.
#

from typing import List, Union
import math

class Word2VecDataGenerator(tf.keras.utils.Sequence):

    def __init__(self, text_samples: Union[str, List[str]], voc: Vocabulary, window_size: int = 4, group_size: int = 100):
        self._window_size = window_size
        self._samples_idx = voc.samples_to_indices(text_samples, include_oov=False)
        self._voc = voc
        self._group_size = group_size

    def __getitem__(self, index):
        start_idx = index * self._group_size
        end_idx = start_idx + self._group_size

        words = np.zeros([0], dtype='int32')
        context_words = np.zeros([0], dtype='int32')
        labels = np.zeros([0], dtype='int8')

        for i in range(start_idx, min(end_idx, self._samples_idx.shape[0])):
            inputs_i, labels_i = self.__get_minibatch__(i)
            words = np.concatenate([words, inputs_i[0]])
            context_words = np.concatenate([context_words, inputs_i[1]])
            labels = np.concatenate([labels, labels_i])

        return [words, context_words], labels

    def __get_minibatch__(self, index):
        sample = self._samples_idx[index]
        couples, labels = tf.keras.preprocessing.sequence.skipgrams(
            sample, self._voc.size, window_size=self._window_size)

        if len(couples) > 0:
            words, context_words = zip(*couples)
        else:
            words, context_words, labels = [[],[],[]]

        words = np.array(words, dtype='int32')
        context_words = np.array(context_words, dtype='int32')
        labels = np.array(labels, dtype='int8')

        return [words, context_words], labels


    def __len__(self):
        return math.ceil(self._samples_idx.shape[0] / self._group_size)

# %%
class SimilarityLogger(tf.keras.callbacks.Callback):

    def __init__(
            self, emb_model: keras.Model, voc: Vocabulary,
            interval: int = 10, validation_size: int = 10, k: int = 5):
        super().__init__()
        self.vocabulary = voc
        self.interval = interval
        self.validation_size = validation_size
        self.embedding_model = emb_model
        self.k = k

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == 0:
            self.print_similarities()

    def on_epoch_end(self, epoch: int, logs: dict = None) -> None:
        if (epoch + 1) % self.interval != 0:
            return
        else:
            self.print_similarities()


    def print_similarities(self, items: Optional[List[str]] = None) -> None:
        if items is None:
            items = list(self.vocabulary.token2index.keys())[1:self.validation_size+1]

        items_idx = np.array([self.vocabulary.token_to_index(item) for item in items])
        print("Calculate embeddings ...")
        item_embeddings = self.get_embeddings(items_idx)
        embeddings = self.get_embeddings()

        print("Calculate similarities ...")
        similarities = cosine_similarity(item_embeddings, embeddings)

        for i in range(0, len(items)):
            item = items[i]
            sim = similarities[i]
            nearest = (-sim).argsort()[1:self.k + 1]

            log = f"Nearest neighbors to `{item}`:"
            for n in nearest:
                n_word = self.vocabulary.index_to_token(n)
                log = f"{log} `{n_word}`"

            print(log)

    def get_embeddings(self, tokens = None) -> np.array:
        if tokens is None:
            tokens = list(self.vocabulary.index2token.keys())

        word_indices = np.array(tokens)
        embeddings = self.embedding_model.predict_on_batch(word_indices)
        return np.squeeze(embeddings)

# %%
sim_logger = SimilarityLogger(embedding_model, vocabulary, interval=5)

history = model.fit(
    Word2VecDataGenerator(samples, vocabulary),
    epochs=80,
    callbacks=[sim_logger])
# Out:
# Epoch 1/80
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `frances` `subways` `wednesday` `rockets` `estimates`
# Nearest neighbors to `menschen`: `zweitkleinsten` `israelis` `lachend` `fachzeitschrift` `seeleute`
# Nearest neighbors to `prozent`: `sexpartner` `staatsgebiet` `hosni` `bannmeile` `quantifizierbarer`
# Nearest neighbors to `deutschland`: `geändert` `einwohnern` `bezirke` `csse` `pflegerischen`
# Nearest neighbors to `millionen`: `milliarden` `staatssekretärs` `subtil` `gedachte` `helikoptergeld`
# Nearest neighbors to `laut`: `zufolge` `wonach` `geschätzte` `ergab` `zusammengebrochen`
# Nearest neighbors to `trump`: `trumps` `dodon` `kronzeugen` `gefecht` `impfen`
# Nearest neighbors to `of`: `spent` `officers` `prosecutor` `fiele` `behind`
# Nearest neighbors to `euro`: `dollar` `unredlich` `milliardenausfälle` `reiseziele` `betrunkenen`
# Nearest neighbors to `to`: `examining` `passierten` `built` `universal` `worn`
# 201/201 [==============================] - 175s 871ms/step - loss: 0.5186
# Epoch 2/80
# 201/201 [==============================] - 170s 846ms/step - loss: 0.5040
# Epoch 3/80
# 201/201 [==============================] - 169s 838ms/step - loss: 0.4939
# Epoch 4/80
# 201/201 [==============================] - 168s 837ms/step - loss: 0.4869
# Epoch 5/80
# 201/201 [==============================] - 168s 836ms/step - loss: 0.4831
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `frances` `subways` `convulsing` `continually` `mittun`
# Nearest neighbors to `menschen`: `zweitkleinsten` `israelis` `weiterverbreitet` `fachzeitschrift` `lachend`
# Nearest neighbors to `prozent`: `hosni` `forman` `quantifizierbarer` `geisterdebatte` `sexpartner`
# Nearest neighbors to `deutschland`: `geändert` `csse` `bereithalten` `einwohnern` `bezirke`
# Nearest neighbors to `millionen`: `milliarden` `staatssekretärs` `subtil` `hypes` `gedachte`
# Nearest neighbors to `laut`: `zufolge` `wonach` `geschätzte` `ergab` `verläufe`
# Nearest neighbors to `trump`: `gefecht` `kronzeugen` `wahlfälschung` `dodon` `trumps`
# Nearest neighbors to `of`: `spent` `prosecutor` `officers` `configuration` `rhode`
# Nearest neighbors to `euro`: `dollar` `reiseziele` `automotoclub` `hauskonzerte` `betrunkenen`
# Nearest neighbors to `to`: `examining` `passierten` `universal` `worn` `allgemeinheit`
# Epoch 6/80
# 201/201 [==============================] - 168s 834ms/step - loss: 0.4817
# Epoch 7/80
# 201/201 [==============================] - 168s 837ms/step - loss: 0.4824
# Epoch 8/80
# 201/201 [==============================] - 169s 839ms/step - loss: 0.4844
# Epoch 9/80
# 201/201 [==============================] - 168s 838ms/step - loss: 0.4875
# Epoch 10/80
# 201/201 [==============================] - 168s 838ms/step - loss: 0.4913
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `subways` `frances` `convulsing` `kreuzfeuer` `postens`
# Nearest neighbors to `menschen`: `zweitkleinsten` `israelis` `weiterverbreitet` `bloßem` `lachend`
# Nearest neighbors to `prozent`: `hosni` `forman` `geisterdebatte` `einzuklinken` `testbestätigung`
# Nearest neighbors to `deutschland`: `geändert` `csse` `bereithalten` `pflegerischen` `bezirke`
# Nearest neighbors to `millionen`: `milliarden` `staatssekretärs` `guadalajara` `subtil` `hypes`
# Nearest neighbors to `laut`: `zufolge` `wonach` `gehöre` `millionenmetropole` `verläufe`
# Nearest neighbors to `trump`: `wahlfälschung` `kronzeugen` `gefecht` `ungezügeltem` `erlasse`
# Nearest neighbors to `of`: `spent` `prosecutor` `configuration` `officers` `rhode`
# Nearest neighbors to `euro`: `reiseziele` `aussteigerprogramm` `torlinie` `angesetzte` `hauskonzerte`
# Nearest neighbors to `to`: `passierten` `examining` `worn` `universal` `implementing`
# Epoch 11/80
# 201/201 [==============================] - 169s 840ms/step - loss: 0.4948
# Epoch 12/80
# 201/201 [==============================] - 168s 835ms/step - loss: 0.4980
# Epoch 13/80
# 201/201 [==============================] - 168s 838ms/step - loss: 0.5002
# Epoch 14/80
# 201/201 [==============================] - 168s 836ms/step - loss: 0.5015
# Epoch 15/80
# 201/201 [==============================] - 169s 837ms/step - loss: 0.5014
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `frances` `convulsing` `subways` `kreuzfeuer` `postens`
# Nearest neighbors to `menschen`: `zweitkleinsten` `weiterverbreitet` `israelis` `bloßem` `spitzenzeiten`
# Nearest neighbors to `prozent`: `hosni` `einzuklinken` `forman` `drogenschmuggel` `informationsleck`
# Nearest neighbors to `deutschland`: `geändert` `csse` `bereithalten` `pflegerischen` `begehrten`
# Nearest neighbors to `millionen`: `milliarden` `staatssekretärs` `guadalajara` `subtil` `hypes`
# Nearest neighbors to `laut`: `zufolge` `wonach` `gehöre` `verläufe` `geschätzte`
# Nearest neighbors to `trump`: `wahlfälschung` `kronzeugen` `gefecht` `erlasse` `ungezügeltem`
# Nearest neighbors to `of`: `prosecutor` `spent` `officers` `configuration` `unbewiesenen`
# Nearest neighbors to `euro`: `reiseziele` `angesetzte` `aussteigerprogramm` `celebrated` `pokalaus`
# Nearest neighbors to `to`: `passierten` `examining` `worn` `sicherheitsexperte` `implementing`
# Epoch 16/80
# 201/201 [==============================] - 169s 839ms/step - loss: 0.4997
# Epoch 17/80
# 201/201 [==============================] - 169s 840ms/step - loss: 0.4962
# Epoch 18/80
# 201/201 [==============================] - 169s 839ms/step - loss: 0.4910
# Epoch 19/80
# 201/201 [==============================] - 169s 839ms/step - loss: 0.4848
# Epoch 20/80
# 201/201 [==============================] - 169s 841ms/step - loss: 0.4780
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `convulsing` `mittun` `subways` `kreuzfeuer` `formelhaft`
# Nearest neighbors to `menschen`: `zweitkleinsten` `israelis` `bloßem` `weiterverbreitet` `spitzenzeiten`
# Nearest neighbors to `prozent`: `drogenschmuggel` `einzuklinken` `forman` `geisterdebatte` `hosni`
# Nearest neighbors to `deutschland`: `geändert` `begehrten` `portals` `csse` `bereithalten`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `helikoptergeld` `protestmails` `hypes`
# Nearest neighbors to `laut`: `zufolge` `wonach` `gehöre` `verläufe` `zusammengebrochen`
# Nearest neighbors to `trump`: `wahlfälschung` `ungezügeltem` `kronzeugen` `gefecht` `dodon`
# Nearest neighbors to `of`: `configuration` `prosecutor` `spent` `unbewiesenen` `rhode`
# Nearest neighbors to `euro`: `reiseziele` `angesetzte` `aussteigerprogramm` `hauskonzerte` `vorfinanzieren`
# Nearest neighbors to `to`: `passierten` `examining` `sicherheitsexperte` `removed` `reinstes`
# Epoch 21/80
# 201/201 [==============================] - 169s 839ms/step - loss: 0.4718
# Epoch 22/80
# 201/201 [==============================] - 170s 844ms/step - loss: 0.4675
# Epoch 23/80
# 201/201 [==============================] - 170s 847ms/step - loss: 0.4648
# Epoch 24/80
# 201/201 [==============================] - 170s 845ms/step - loss: 0.4634
# Epoch 25/80
# 201/201 [==============================] - 170s 845ms/step - loss: 0.4624
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `convulsing` `mittun` `formelhaft` `subways` `postens`
# Nearest neighbors to `menschen`: `zweitkleinsten` `bloßem` `israelis` `weiterverbreitet` `spitzenzeiten`
# Nearest neighbors to `prozent`: `geisterdebatte` `drogenschmuggel` `forman` `einzuklinken` `exponentially`
# Nearest neighbors to `deutschland`: `geändert` `csse` `portals` `bezirke` `begehrten`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `regierungspräsident` `subtil` `protestmails`
# Nearest neighbors to `laut`: `zufolge` `wonach` `gehöre` `verläufe` `zusammengebrochen`
# Nearest neighbors to `trump`: `ungezügeltem` `kronzeugen` `wahlfälschung` `gefecht` `erlasse`
# Nearest neighbors to `of`: `tonaufnahmen` `configuration` `dsmb` `prosecutor` `spent`
# Nearest neighbors to `euro`: `reiseziele` `angesetzte` `aussteigerprogramm` `bugatti` `vorfinanzieren`
# Nearest neighbors to `to`: `passierten` `examining` `beleidigende` `removed` `sicherheitsexperte`
# Epoch 26/80
# 201/201 [==============================] - 170s 846ms/step - loss: 0.4618
# Epoch 27/80
# 201/201 [==============================] - 170s 845ms/step - loss: 0.4613
# Epoch 28/80
# 201/201 [==============================] - 170s 848ms/step - loss: 0.4609
# Epoch 29/80
# 201/201 [==============================] - 171s 846ms/step - loss: 0.4605
# Epoch 30/80
# 201/201 [==============================] - 171s 847ms/step - loss: 0.4603
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `convulsing` `mittun` `formelhaft` `kashmir` `veitshöchheim`
# Nearest neighbors to `menschen`: `zweitkleinsten` `israelis` `bloßem` `ursachen` `koalition`
# Nearest neighbors to `prozent`: `geisterdebatte` `drogenschmuggel` `einzuklinken` `forman` `gesamtsiegerinnen`
# Nearest neighbors to `deutschland`: `geändert` `wilmington` `bezirke` `portals` `csse`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `staatssekretärs` `subtil` `hypes`
# Nearest neighbors to `laut`: `zufolge` `wonach` `gehöre` `zusammengebrochen` `verläufe`
# Nearest neighbors to `trump`: `ungezügeltem` `kronzeugen` `gefecht` `wahlfälschung` `erlasse`
# Nearest neighbors to `of`: `tonaufnahmen` `dsmb` `configuration` `prosecutor` `zerbrochen`
# Nearest neighbors to `euro`: `reiseziele` `aussteigerprogramm` `hauskonzerte` `angesetzte` `bugatti`
# Nearest neighbors to `to`: `passierten` `examining` `beleidigende` `removed` `sicherheitsexperte`
# Epoch 31/80
# 201/201 [==============================] - 171s 847ms/step - loss: 0.4600
# Epoch 32/80
# 201/201 [==============================] - 170s 846ms/step - loss: 0.4598
# Epoch 33/80
# 201/201 [==============================] - 171s 850ms/step - loss: 0.4595
# Epoch 34/80
# 201/201 [==============================] - 170s 847ms/step - loss: 0.4594
# Epoch 35/80
# 201/201 [==============================] - 171s 849ms/step - loss: 0.4592
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `formelhaft` `convulsing` `mittun` `kashmir` `veitshöchheim`
# Nearest neighbors to `menschen`: `zweitkleinsten` `israelis` `bloßem` `koalition` `ursachen`
# Nearest neighbors to `prozent`: `geisterdebatte` `drogenschmuggel` `forman` `granateneinschlag` `exponentially`
# Nearest neighbors to `deutschland`: `geändert` `wilmington` `portals` `nachbarländer` `weltmeisterin`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `staatssekretärs` `subtil` `regierungspräsident`
# Nearest neighbors to `laut`: `zufolge` `wonach` `gehöre` `zusammengebrochen` `mutanten`
# Nearest neighbors to `trump`: `kronzeugen` `ungezügeltem` `erlasse` `gefecht` `wahlfälschung`
# Nearest neighbors to `of`: `tonaufnahmen` `dsmb` `configuration` `behind` `zerbrochen`
# Nearest neighbors to `euro`: `reiseziele` `aussteigerprogramm` `hauskonzerte` `angesetzte` `pokalaus`
# Nearest neighbors to `to`: `passierten` `beleidigende` `examining` `removed` `sicherheitsexperte`
# Epoch 36/80
# 201/201 [==============================] - 170s 848ms/step - loss: 0.4590
# Epoch 37/80
# 201/201 [==============================] - 170s 847ms/step - loss: 0.4588
# Epoch 38/80
# 201/201 [==============================] - 171s 847ms/step - loss: 0.4587
# Epoch 39/80
# 201/201 [==============================] - 170s 845ms/step - loss: 0.4585
# Epoch 40/80
# 201/201 [==============================] - 170s 843ms/step - loss: 0.4584
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `formelhaft` `convulsing` `mittun` `kashmir` `veitshöchheim`
# Nearest neighbors to `menschen`: `zweitkleinsten` `israelis` `bloßem` `koalition` `ursachen`
# Nearest neighbors to `prozent`: `geisterdebatte` `drogenschmuggel` `informationsleck` `forman` `exponentially`
# Nearest neighbors to `deutschland`: `geändert` `wilmington` `nachbarländer` `portals` `bezirke`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `subtil` `staatssekretärs` `regierungspräsident`
# Nearest neighbors to `laut`: `zufolge` `wonach` `gehöre` `zusammengebrochen` `mutanten`
# Nearest neighbors to `trump`: `kronzeugen` `ungezügeltem` `geknackt` `erlasse` `wahlfälschung`
# Nearest neighbors to `of`: `tonaufnahmen` `dsmb` `behind` `zerbrochen` `configuration`
# Nearest neighbors to `euro`: `reiseziele` `aussteigerprogramm` `hauskonzerte` `angesetzte` `bugatti`
# Nearest neighbors to `to`: `passierten` `beleidigende` `examining` `removed` `reinstes`
# Epoch 41/80
# 201/201 [==============================] - 170s 844ms/step - loss: 0.4583
# Epoch 42/80
# 201/201 [==============================] - 170s 844ms/step - loss: 0.4582
# Epoch 43/80
# 201/201 [==============================] - 169s 842ms/step - loss: 0.4582
# Epoch 44/80
# 201/201 [==============================] - 169s 841ms/step - loss: 0.4579
# Epoch 45/80
# 201/201 [==============================] - 169s 844ms/step - loss: 0.4579
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `formelhaft` `convulsing` `mittun` `kashmir` `veitshöchheim`
# Nearest neighbors to `menschen`: `zweitkleinsten` `israelis` `bloßem` `koalition` `ursachen`
# Nearest neighbors to `prozent`: `geisterdebatte` `informationsleck` `drogenschmuggel` `exponentially` `forman`
# Nearest neighbors to `deutschland`: `geändert` `wilmington` `nachbarländer` `portals` `bezirke`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `subtil` `staatssekretärs` `hypes`
# Nearest neighbors to `laut`: `zufolge` `wonach` `zusammengebrochen` `gehöre` `erforderlich`
# Nearest neighbors to `trump`: `kronzeugen` `ungezügeltem` `geknackt` `erlasse` `widerstandsfähigkeit`
# Nearest neighbors to `of`: `tonaufnahmen` `dsmb` `zerbrochen` `behind` `configuration`
# Nearest neighbors to `euro`: `reiseziele` `aussteigerprogramm` `hauskonzerte` `flugzeugbauers` `bugatti`
# Nearest neighbors to `to`: `examining` `beleidigende` `passierten` `lieferversprechen` `removed`
# Epoch 46/80
# 201/201 [==============================] - 169s 841ms/step - loss: 0.4577
# Epoch 47/80
# 201/201 [==============================] - 170s 843ms/step - loss: 0.4577
# Epoch 48/80
# 201/201 [==============================] - 170s 842ms/step - loss: 0.4576
# Epoch 49/80
# 201/201 [==============================] - 170s 844ms/step - loss: 0.4575
# Epoch 50/80
# 201/201 [==============================] - 170s 844ms/step - loss: 0.4574
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `formelhaft` `convulsing` `kashmir` `mittun` `veitshöchheim`
# Nearest neighbors to `menschen`: `zweitkleinsten` `israelis` `bloßem` `koalition` `ursachen`
# Nearest neighbors to `prozent`: `geisterdebatte` `informationsleck` `forman` `drogenschmuggel` `granateneinschlag`
# Nearest neighbors to `deutschland`: `geändert` `nachbarländer` `wilmington` `portals` `bezirke`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `subtil` `staatssekretärs` `regierungspräsident`
# Nearest neighbors to `laut`: `zufolge` `wonach` `erforderlich` `zusammengebrochen` `mutanten`
# Nearest neighbors to `trump`: `kronzeugen` `ungezügeltem` `geknackt` `erlasse` `gefecht`
# Nearest neighbors to `of`: `tonaufnahmen` `dsmb` `zerbrochen` `geschäftsbeziehung` `behind`
# Nearest neighbors to `euro`: `reiseziele` `aussteigerprogramm` `hauskonzerte` `bugatti` `flugzeugbauers`
# Nearest neighbors to `to`: `examining` `beleidigende` `passierten` `lieferversprechen` `removed`
# Epoch 51/80
# 201/201 [==============================] - 170s 844ms/step - loss: 0.4573
# Epoch 52/80
# 201/201 [==============================] - 170s 842ms/step - loss: 0.4572
# Epoch 53/80
# 201/201 [==============================] - 170s 843ms/step - loss: 0.4571
# Epoch 54/80
# 201/201 [==============================] - 170s 844ms/step - loss: 0.4571
# Epoch 55/80
# 201/201 [==============================] - 170s 843ms/step - loss: 0.4571
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `formelhaft` `convulsing` `kashmir` `zerbombte` `mittun`
# Nearest neighbors to `menschen`: `zweitkleinsten` `israelis` `koalition` `bloßem` `ali`
# Nearest neighbors to `prozent`: `geisterdebatte` `forman` `granateneinschlag` `informationsleck` `drogenschmuggel`
# Nearest neighbors to `deutschland`: `geändert` `nachbarländer` `wilmington` `tatsächlichen` `portals`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `staatssekretärs` `subtil` `misslicherweise`
# Nearest neighbors to `laut`: `zufolge` `wonach` `erforderlich` `mutanten` `zusammengebrochen`
# Nearest neighbors to `trump`: `kronzeugen` `ungezügeltem` `geknackt` `erlasse` `gefecht`
# Nearest neighbors to `of`: `tonaufnahmen` `dsmb` `behind` `zerbrochen` `spotify`
# Nearest neighbors to `euro`: `reiseziele` `hauskonzerte` `aussteigerprogramm` `professioneller` `bugatti`
# Nearest neighbors to `to`: `examining` `beleidigende` `passierten` `lieferversprechen` `luftholen`
# Epoch 56/80
# 201/201 [==============================] - 170s 842ms/step - loss: 0.4568
# Epoch 57/80
# 201/201 [==============================] - 170s 845ms/step - loss: 0.4569
# Epoch 58/80
# 201/201 [==============================] - 170s 844ms/step - loss: 0.4568
# Epoch 59/80
# 201/201 [==============================] - 170s 841ms/step - loss: 0.4568
# Epoch 60/80
# 201/201 [==============================] - 170s 845ms/step - loss: 0.4566
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `formelhaft` `convulsing` `kashmir` `zerbombte` `veitshöchheim`
# Nearest neighbors to `menschen`: `zweitkleinsten` `koalition` `israelis` `bloßem` `ali`
# Nearest neighbors to `prozent`: `geisterdebatte` `forman` `granateneinschlag` `drogenschmuggel` `informationsleck`
# Nearest neighbors to `deutschland`: `geändert` `nachbarländer` `wilmington` `tatsächlichen` `bezirke`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `staatssekretärs` `subtil` `misslicherweise`
# Nearest neighbors to `laut`: `zufolge` `wonach` `erforderlich` `mutanten` `zusammengebrochen`
# Nearest neighbors to `trump`: `kronzeugen` `ungezügeltem` `geknackt` `erlasse` `gefecht`
# Nearest neighbors to `of`: `tonaufnahmen` `dsmb` `spotify` `geschäftsbeziehung` `zerbrochen`
# Nearest neighbors to `euro`: `reiseziele` `professioneller` `hauskonzerte` `aussteigerprogramm` `reschke`
# Nearest neighbors to `to`: `beleidigende` `examining` `passierten` `lieferversprechen` `armbänder`
# Epoch 61/80
# 201/201 [==============================] - 170s 846ms/step - loss: 0.4567
# Epoch 62/80
# 201/201 [==============================] - 170s 843ms/step - loss: 0.4566
# Epoch 63/80
# 201/201 [==============================] - 170s 843ms/step - loss: 0.4564
# Epoch 64/80
#  - ETA: 15s - loss: 0.4563
# Epoch 65/80
# 201/201 [==============================] - 170s 845ms/step - loss: 0.4565
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `formelhaft` `convulsing` `kashmir` `figen` `zerbombte`
# Nearest neighbors to `menschen`: `zweitkleinsten` `koalition` `israelis` `bloßem` `ali`
# Nearest neighbors to `prozent`: `geisterdebatte` `granateneinschlag` `informationsleck` `forman` `drogenschmuggel`
# Nearest neighbors to `deutschland`: `geändert` `nachbarländer` `wilmington` `tatsächlichen` `bezirke`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `staatssekretärs` `subtil` `misslicherweise`
# Nearest neighbors to `laut`: `zufolge` `wonach` `erforderlich` `mutanten` `zusammengebrochen`
# Nearest neighbors to `trump`: `kronzeugen` `ungezügeltem` `geknackt` `erlasse` `gefecht`
# Nearest neighbors to `of`: `tonaufnahmen` `dsmb` `spotify` `zerbrochen` `reed`
# Nearest neighbors to `euro`: `reiseziele` `professioneller` `reschke` `hauskonzerte` `aussteigerprogramm`
# Nearest neighbors to `to`: `beleidigende` `examining` `passierten` `lieferversprechen` `armbänder`
# Epoch 66/80
# 201/201 [==============================] - 171s 850ms/step - loss: 0.4564
# Epoch 67/80
# 201/201 [==============================] - 173s 860ms/step - loss: 0.4564
# Epoch 68/80
# 201/201 [==============================] - 172s 855ms/step - loss: 0.4564
# Epoch 69/80
# 201/201 [==============================] - 172s 855ms/step - loss: 0.4563
# Epoch 70/80
# 201/201 [==============================] - 171s 851ms/step - loss: 0.4562
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `formelhaft` `convulsing` `figen` `zerbombte` `kashmir`
# Nearest neighbors to `menschen`: `zweitkleinsten` `koalition` `israelis` `jerusalem` `bloßem`
# Nearest neighbors to `prozent`: `geisterdebatte` `granateneinschlag` `informationsleck` `exponentially` `forman`
# Nearest neighbors to `deutschland`: `geändert` `nachbarländer` `wilmington` `tatsächlichen` `ansatz`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `staatssekretärs` `subtil` `misslicherweise`
# Nearest neighbors to `laut`: `zufolge` `wonach` `erforderlich` `mutanten` `zusammengebrochen`
# Nearest neighbors to `trump`: `kronzeugen` `ungezügeltem` `geknackt` `erlasse` `gefecht`
# Nearest neighbors to `of`: `tonaufnahmen` `dsmb` `spotify` `reed` `geschäftsbeziehung`
# Nearest neighbors to `euro`: `reiseziele` `reschke` `professioneller` `aussteigerprogramm` `hauskonzerte`
# Nearest neighbors to `to`: `beleidigende` `examining` `passierten` `lieferversprechen` `armbänder`
# Epoch 71/80
# 201/201 [==============================] - 171s 852ms/step - loss: 0.4563
# Epoch 72/80
# 201/201 [==============================] - 172s 854ms/step - loss: 0.4561
# Epoch 73/80
# 201/201 [==============================] - 171s 850ms/step - loss: 0.4560
# Epoch 74/80
# 201/201 [==============================] - 172s 855ms/step - loss: 0.4560
# Epoch 75/80
# 201/201 [==============================] - 173s 859ms/step - loss: 0.4561
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `formelhaft` `convulsing` `zerbombte` `knöcheltiefe` `figen`
# Nearest neighbors to `menschen`: `zweitkleinsten` `koalition` `israelis` `bloßem` `jerusalem`
# Nearest neighbors to `prozent`: `geisterdebatte` `granateneinschlag` `informationsleck` `forman` `persönlichsten`
# Nearest neighbors to `deutschland`: `geändert` `nachbarländer` `wilmington` `tatsächlichen` `ansatz`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `staatssekretärs` `subtil` `misslicherweise`
# Nearest neighbors to `laut`: `zufolge` `wonach` `erforderlich` `mutanten` `zusammengebrochen`
# Nearest neighbors to `trump`: `kronzeugen` `geknackt` `ungezügeltem` `erlasse` `gefecht`
# Nearest neighbors to `of`: `tonaufnahmen` `dsmb` `reed` `spotify` `zerbrochen`
# Nearest neighbors to `euro`: `reiseziele` `reschke` `professioneller` `hauskonzerte` `aussteigerprogramm`
# Nearest neighbors to `to`: `beleidigende` `examining` `passierten` `lieferversprechen` `armbänder`
# Epoch 76/80
# 201/201 [==============================] - 170s 846ms/step - loss: 0.4560
# Epoch 77/80
# 201/201 [==============================] - 170s 843ms/step - loss: 0.4560
# Epoch 78/80
# 201/201 [==============================] - 170s 845ms/step - loss: 0.4559
# Epoch 79/80
# 201/201 [==============================] - 171s 852ms/step - loss: 0.4559
# Epoch 80/80
# 201/201 [==============================] - 171s 851ms/step - loss: 0.4558
# Calculate embeddings ...
# Calculate similarities ...
# Nearest neighbors to `the`: `formelhaft` `zerbombte` `knöcheltiefe` `convulsing` `figen`
# Nearest neighbors to `menschen`: `zweitkleinsten` `koalition` `israelis` `bloßem` `jerusalem`
# Nearest neighbors to `prozent`: `geisterdebatte` `granateneinschlag` `informationsleck` `exponentially` `persönlichsten`
# Nearest neighbors to `deutschland`: `geändert` `nachbarländer` `wilmington` `tatsächlichen` `ansatz`
# Nearest neighbors to `millionen`: `milliarden` `guadalajara` `subtil` `staatssekretärs` `misslicherweise`
# Nearest neighbors to `laut`: `zufolge` `wonach` `erforderlich` `mutanten` `zusammengebrochen`
# Nearest neighbors to `trump`: `kronzeugen` `geknackt` `ungezügeltem` `erlasse` `gefecht`
# Nearest neighbors to `of`: `tonaufnahmen` `dsmb` `reed` `spotify` `zerbrochen`
# Nearest neighbors to `euro`: `reiseziele` `reschke` `professioneller` `aussteigerprogramm` `hauskonzerte`
# Nearest neighbors to `to`: `beleidigende` `examining` `passierten` `lieferversprechen` `armbänder`

# %%
model.save('./data/model/training_model')
embedding_model.save('./data/model/embedding_model')
# Out:
# INFO:tensorflow:Assets written to: ./data/model/training_model/assets
# INFO:tensorflow:Assets written to: ./data/model/embedding_model/assets

# %%
[ k for k in vocabulary.token2index.keys() if "frank" in k ]
# Out:
# ['frankreich',
#  'frankfurt',
#  'frankfurter',
#  'frank',
#  'franke',
#  'oberfranken',
#  'franklin',
#  'frankenstein',
#  'unterfranken',
#  'mittelfranken',
#  'südfrankreich',
#  'frankel',
#  'frankenstrat',
#  'frankes',
#  'frankopan',
#  'unionsfranktion',
#  'frankenderby',
#  'frankieren',
#  'frankokanadierin',
#  'frankofonen',
#  'frankly',
#  'frankenberg',
#  'frankeich',
#  'franken',
#  'frankowski',
#  'franklins',
#  'nordfrankreich',
#  'kontinentalfrankreich']

# %%
sim_logger.print_similarities(items=['frankreich', 'frankfurt'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d960dc9ddc0> in <module>
# ----> 1 sim_logger.print_similarities(items=['frankreich', 'frankfurt'])
#
# NameError: name 'sim_logger' is not defined

# %%
# !pwd
# Out:
# /home/michael/Workspaces/thesis--news-preparation

# %%
list(vocabulary.token2index.keys())[1:10]
# Out:
# ['the',
#  'mensch',
#  'land',
#  'prozent',
#  'deutschland',
#  'woche',
#  'million',
#  'stehen',
#  'laut']
